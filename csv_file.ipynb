# %% [markdown]
# <a href="https://colab.research.google.com/github/DevpriyaSaini/placement-predictor/blob/main/csv_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Coffe_sales.csv")

# %%
df
# Out:
#       hour_of_day cash_type  money    coffee_name Time_of_Day Weekday  \
# 0              10      card  38.70          Latte     Morning     Fri
# 1              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 2              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 3              13      card  28.90      Americano   Afternoon     Fri
# 4              13      card  38.70          Latte   Afternoon     Fri
# ...           ...       ...    ...            ...         ...     ...
# 3542           10      card  35.76     Cappuccino     Morning     Sun
# 3543           14      card  35.76          Cocoa   Afternoon     Sun
# 3544           14      card  35.76          Cocoa   Afternoon     Sun
# 3545           15      card  25.96      Americano   Afternoon     Sun
# 3546           18      card  35.76          Latte       Night     Sun
#
#      Month_name  Weekdaysort  Monthsort        Date             Time
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Coffe_sales.csv")

# %% [markdown]
# 3.opening a csv file from url

# %%
import requests
from io import StringIO

url = 'https://github.com/campusx-official/100-Days-Of-ML-Code/blob/master/datasets/studentscores.csv'
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36"
}

req = requests.get(url, headers=headers)
data=StringIO(req.text)
pd.read_csv(data,error_bad_lines=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3269923313.py in <cell line: 0>()
#       9 req = requests.get(url, headers=headers)
#      10 data=StringIO(req.text)
# ---> 11 pd.read_csv(data,error_bad_lines=False)
#
# TypeError: read_csv() got an unexpected keyword argument 'error_bad_lines'

# %% [markdown]
# 4.set parameter like -> or ,

# %%
pd.read_csv("/content/Coffe_sales.csv",sep='/t')
# Out:
# /tmp/ipython-input-775078104.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   pd.read_csv("/content/Coffe_sales.csv",sep='/t')
#      hour_of_day,cash_type,money,coffee_name,Time_of_Day,Weekday,Month_name,Weekdaysort,Monthsort,Date,Time
# 0     10,card,38.7,Latte,Morning,Fri,Mar,5,3,2024-03...
# 1     12,card,38.7,Hot Chocolate,Afternoon,Fri,Mar,5...
# 2     12,card,38.7,Hot Chocolate,Afternoon,Fri,Mar,5...
# 3     13,card,28.9,Americano,Afternoon,Fri,Mar,5,3,2...
# 4     13,card,38.7,Latte,Afternoon,Fri,Mar,5,3,2024-...
# ...                                                 ...
# 3542  10,card,35.76,Cappuccino,Morning,Sun,Mar,7,3,2...
# 3543  14,card,35.76,Cocoa,Afternoon,Sun,Mar,7,3,2025...
# 3544  14,card,35.76,Cocoa,Afternoon,Sun,Mar,7,3,2025...
# ...

# %% [markdown]
# to add colom name

# %%
pd.read_csv("/content/Coffe_sales.csv",sep='/t',names=['A','B','C','D'])
# Out:
# /tmp/ipython-input-2202063265.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   pd.read_csv("/content/Coffe_sales.csv",sep='/t',names=['A','B','C','D'])
#                                                       A   B   C   D
# 0     hour_of_day,cash_type,money,coffee_name,Time_o... NaN NaN NaN
# 1     10,card,38.7,Latte,Morning,Fri,Mar,5,3,2024-03... NaN NaN NaN
# 2     12,card,38.7,Hot Chocolate,Afternoon,Fri,Mar,5... NaN NaN NaN
# 3     12,card,38.7,Hot Chocolate,Afternoon,Fri,Mar,5... NaN NaN NaN
# 4     13,card,28.9,Americano,Afternoon,Fri,Mar,5,3,2... NaN NaN NaN
# ...                                                 ...  ..  ..  ..
# 3543  10,card,35.76,Cappuccino,Morning,Sun,Mar,7,3,2... NaN NaN NaN
# 3544  14,card,35.76,Cocoa,Afternoon,Sun,Mar,7,3,2025... NaN NaN NaN
# ...

# %% [markdown]
# to convert any colom into index colom

# %%
pd.read_csv("/content/Coffe_sales.csv",index_col=0)
# Out:
#             cash_type  money    coffee_name Time_of_Day Weekday Month_name  \
# hour_of_day
# 10               card  38.70          Latte     Morning     Fri        Mar
# 12               card  38.70  Hot Chocolate   Afternoon     Fri        Mar
# 12               card  38.70  Hot Chocolate   Afternoon     Fri        Mar
# 13               card  28.90      Americano   Afternoon     Fri        Mar
# 13               card  38.70          Latte   Afternoon     Fri        Mar
# ...               ...    ...            ...         ...     ...        ...
# 10               card  35.76     Cappuccino     Morning     Sun        Mar
# 14               card  35.76          Cocoa   Afternoon     Sun        Mar
# 14               card  35.76          Cocoa   Afternoon     Sun        Mar
# 15               card  25.96      Americano   Afternoon     Sun        Mar
# 18               card  35.76          Latte       Night     Sun        Mar
#
# ...

# %% [markdown]
# Header parameter( if model read heading as data then shift heading)

# %%
pd.read_csv("/content/Coffe_sales.csv",header=1)
# Out:
#       10  card   38.7                Latte    Morning  Fri  Mar  5  3  \
# 0     12  card  38.70        Hot Chocolate  Afternoon  Fri  Mar  5  3
# 1     12  card  38.70        Hot Chocolate  Afternoon  Fri  Mar  5  3
# 2     13  card  28.90            Americano  Afternoon  Fri  Mar  5  3
# 3     13  card  38.70                Latte  Afternoon  Fri  Mar  5  3
# 4     15  card  33.80  Americano with Milk  Afternoon  Fri  Mar  5  3
# ...   ..   ...    ...                  ...        ...  ...  ... .. ..
# 3541  10  card  35.76           Cappuccino    Morning  Sun  Mar  7  3
# 3542  14  card  35.76                Cocoa  Afternoon  Sun  Mar  7  3
# 3543  14  card  35.76                Cocoa  Afternoon  Sun  Mar  7  3
# 3544  15  card  25.96            Americano  Afternoon  Sun  Mar  7  3
# 3545  18  card  35.76                Latte      Night  Sun  Mar  7  3
#
#       2024-03-01  10:15:50.520000
# 0     2024-03-01  12:19:22.539000
# 1     2024-03-01  12:20:18.089000
# ...

# %% [markdown]
# if wants some colom

# %%
pd.read_csv("/content/Coffe_sales.csv",usecols=['coffee_name','money','cash_type'])
# Out:
#      cash_type  money    coffee_name
# 0         card  38.70          Latte
# 1         card  38.70  Hot Chocolate
# 2         card  38.70  Hot Chocolate
# 3         card  28.90      Americano
# 4         card  38.70          Latte
# ...        ...    ...            ...
# 3542      card  35.76     Cappuccino
# 3543      card  35.76          Cocoa
# 3544      card  35.76          Cocoa
# 3545      card  25.96      Americano
# 3546      card  35.76          Latte
#
# [3547 rows x 3 columns]

# %% [markdown]
# squeeze paramater(will be data series)

# %%
pd.read_csv("/content/Coffe_sales.csv",usecols=['coffee_name'],squeeze=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-767556101.py in <cell line: 0>()
# ----> 1 pd.read_csv("/content/Coffe_sales.csv",usecols=['coffee_name'],squeeze=True)
#
# TypeError: read_csv() got an unexpected keyword argument 'squeeze'

# %% [markdown]
# skiprows and nrows

# %%
pd.read_csv("/content/Coffe_sales.csv",skiprows=1)
# Out:
#       10  card   38.7                Latte    Morning  Fri  Mar  5  3  \
# 0     12  card  38.70        Hot Chocolate  Afternoon  Fri  Mar  5  3
# 1     12  card  38.70        Hot Chocolate  Afternoon  Fri  Mar  5  3
# 2     13  card  28.90            Americano  Afternoon  Fri  Mar  5  3
# 3     13  card  38.70                Latte  Afternoon  Fri  Mar  5  3
# 4     15  card  33.80  Americano with Milk  Afternoon  Fri  Mar  5  3
# ...   ..   ...    ...                  ...        ...  ...  ... .. ..
# 3541  10  card  35.76           Cappuccino    Morning  Sun  Mar  7  3
# 3542  14  card  35.76                Cocoa  Afternoon  Sun  Mar  7  3
# 3543  14  card  35.76                Cocoa  Afternoon  Sun  Mar  7  3
# 3544  15  card  25.96            Americano  Afternoon  Sun  Mar  7  3
# 3545  18  card  35.76                Latte      Night  Sun  Mar  7  3
#
#       2024-03-01  10:15:50.520000
# 0     2024-03-01  12:19:22.539000
# 1     2024-03-01  12:20:18.089000
# ...

# %%
pd.read_csv("/content/Coffe_sales.csv", nrows=100)
# Out:
#     hour_of_day cash_type  money          coffee_name Time_of_Day Weekday  \
# 0            10      card   38.7                Latte     Morning     Fri
# 1            12      card   38.7        Hot Chocolate   Afternoon     Fri
# 2            12      card   38.7        Hot Chocolate   Afternoon     Fri
# 3            13      card   28.9            Americano   Afternoon     Fri
# 4            13      card   38.7                Latte   Afternoon     Fri
# ..          ...       ...    ...                  ...         ...     ...
# 95           15      card   38.7                Latte   Afternoon     Thu
# 96           16      card   33.8  Americano with Milk   Afternoon     Thu
# 97           16      card   24.0             Espresso   Afternoon     Thu
# 98           18      card   38.7        Hot Chocolate       Night     Thu
# 99           19      card   28.9              Cortado       Night     Thu
#
#    Month_name  Weekdaysort  Monthsort        Date             Time
# ...

# %% [markdown]
# UnicodeDecodeError

# %%
pd.read_csv("/content/Coffe_sales.csv",encoding='latin-1')
# Out:
#       hour_of_day cash_type  money    coffee_name Time_of_Day Weekday  \
# 0              10      card  38.70          Latte     Morning     Fri
# 1              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 2              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 3              13      card  28.90      Americano   Afternoon     Fri
# 4              13      card  38.70          Latte   Afternoon     Fri
# ...           ...       ...    ...            ...         ...     ...
# 3542           10      card  35.76     Cappuccino     Morning     Sun
# 3543           14      card  35.76          Cocoa   Afternoon     Sun
# 3544           14      card  35.76          Cocoa   Afternoon     Sun
# 3545           15      card  25.96      Americano   Afternoon     Sun
# 3546           18      card  35.76          Latte       Night     Sun
#
#      Month_name  Weekdaysort  Monthsort        Date             Time
# ...

# %% [markdown]
# skip bad line(parser error)

# %%
pd.read_csv("/content/Coffe_sales.csv",error_bad_lines=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2996421728.py in <cell line: 0>()
# ----> 1 pd.read_csv("/content/Coffe_sales.csv",error_bad_lines=False)
#
# TypeError: read_csv() got an unexpected keyword argument 'error_bad_lines'

# %% [markdown]
# dtypes parameter

# %%
pd.read_csv("/content/Coffe_sales.csv",dtype={'money':'float'})
# Out:
#       hour_of_day cash_type  money    coffee_name Time_of_Day Weekday  \
# 0              10      card  38.70          Latte     Morning     Fri
# 1              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 2              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 3              13      card  28.90      Americano   Afternoon     Fri
# 4              13      card  38.70          Latte   Afternoon     Fri
# ...           ...       ...    ...            ...         ...     ...
# 3542           10      card  35.76     Cappuccino     Morning     Sun
# 3543           14      card  35.76          Cocoa   Afternoon     Sun
# 3544           14      card  35.76          Cocoa   Afternoon     Sun
# 3545           15      card  25.96      Americano   Afternoon     Sun
# 3546           18      card  35.76          Latte       Night     Sun
#
#      Month_name  Weekdaysort  Monthsort        Date             Time
# ...

# %% [markdown]
# handling dates

# %%
pd.read_csv("/content/Coffe_sales.csv",parse_dates=['Date'])
# Out:
#       hour_of_day cash_type  money    coffee_name Time_of_Day Weekday  \
# 0              10      card  38.70          Latte     Morning     Fri
# 1              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 2              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 3              13      card  28.90      Americano   Afternoon     Fri
# 4              13      card  38.70          Latte   Afternoon     Fri
# ...           ...       ...    ...            ...         ...     ...
# 3542           10      card  35.76     Cappuccino     Morning     Sun
# 3543           14      card  35.76          Cocoa   Afternoon     Sun
# 3544           14      card  35.76          Cocoa   Afternoon     Sun
# 3545           15      card  25.96      Americano   Afternoon     Sun
# 3546           18      card  35.76          Latte       Night     Sun
#
#      Month_name  Weekdaysort  Monthsort       Date             Time
# ...

# %% [markdown]
# convertors

# %%
def rename(name):
  if name=='Latte':
    return 'Coffee'
  else:
    return name

# %%
rename("Latte")
# Out:
# 'Coffee'

# %% [markdown]
# na value parameter

# %%
pd.read_csv("/content/Coffe_sales.csv",na_values=['Latte'])
# Out:
#       hour_of_day cash_type  money    coffee_name Time_of_Day Weekday  \
# 0              10      card  38.70            NaN     Morning     Fri
# 1              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 2              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 3              13      card  28.90      Americano   Afternoon     Fri
# 4              13      card  38.70            NaN   Afternoon     Fri
# ...           ...       ...    ...            ...         ...     ...
# 3542           10      card  35.76     Cappuccino     Morning     Sun
# 3543           14      card  35.76          Cocoa   Afternoon     Sun
# 3544           14      card  35.76          Cocoa   Afternoon     Sun
# 3545           15      card  25.96      Americano   Afternoon     Sun
# 3546           18      card  35.76            NaN       Night     Sun
#
#      Month_name  Weekdaysort  Monthsort        Date             Time
# ...

# %% [markdown]
# loading divide in chunck

# %%
dfs=pd.read_csv("/content/Coffe_sales.csv",chunksize=100)

# %%
for chunks in dfs: print(chunks.size)
# Out:
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 517
