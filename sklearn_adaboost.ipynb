# %% [markdown]
# <a href="https://colab.research.google.com/github/DevpriyaSaini/ML-100/blob/main/sklearn_adaboost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles

# %%
np.random.seed(42)
X, y=make_circles(n_samples=500,factor=0.1,noise=0.35,random_state=42)

# %%
plt.scatter(X[:,0],X[:,1],c=y)
plt.show()

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
from sklearn.model_selection import cross_val_score

# %%
abc=AdaBoostClassifier(n_estimators=1500,learning_rate=0.1
                       )

# %%
np.mean(cross_val_score(abc,X,y,cv=5))
# Out:
# np.float64(0.828)

# %%
abc.fit(X,y)
# Out:
# AdaBoostClassifier(learning_rate=0.1, n_estimators=1500)

# %%
def plot_decision_boundry(clf):
  plt.figure(figsize=(10,10))
  plot_decision_regions(X,y,clf=clf,legend=2)
  plt.show()
plot_decision_boundry(abc)

# %%
#also can add grid search CV
